# %% [markdown]
# # Python Programming Fundamentals for AI & Machine Learning
# Interview-ready notebook covering Python, NumPy, Pandas and a mini AI/ML preprocessing example.

# %% [markdown]
# ## Variables and Data Types
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
# Variables
name = "Prathibha"
age = 21
cgpa = 9.12
is_student = True

# Print values
print(name)
print(age)
print(cgpa)
print(is_student)

# Check data types
print(type(name), type(age), type(cgpa), type(is_student))

# %% [markdown]
# ## Operators
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
a,b=10,3
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Floor:",a//b)
print("Modulus:",a%b)
print("Power:",a**b)
print(a>b,a==b,a!=b)

# %% [markdown]
# ## Conditional Statements
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
marks=82
if marks>=90:
    print("Grade A")
elif marks>=75:
    print("Grade B")
else:
    print("Grade C")

# %% [markdown]
# ## Loops
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
for i in range(1,6):
    print("For:",i)

count=1
while count<=5:
    print("While:",count)
    count+=1

# %% [markdown]
# ## Lists, Tuples, Sets, Dictionaries
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
fruits=["Apple","Banana","Mango"]
fruits.append("Orange")
print(fruits)

colors=("Red","Green","Blue")
print(colors)

nums={1,2,2,3}
print(nums)

student={"Name":"Prathibha","CGPA":9.12}
print(student["Name"])

# %% [markdown]
# ## Functions
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
def square(x):
    return x*x

print(square(5))

def greet(name):
    print(f"Hello {name}")

greet("AI Learner")

# %% [markdown]
# ## Lambda and List Comprehension
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
nums=[1,2,3,4,5]
squares=[x*x for x in nums]
print(squares)

double=list(map(lambda x:x*2,nums))
print(double)

# %% [markdown]
# ## Exception Handling
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
try:
    x=10/0
except ZeroDivisionError:
    print("Cannot divide by zero")
finally:
    print("Program finished")

# %% [markdown]
# ## File Handling
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
with open("sample.txt","w") as f:
    f.write("Hello AI")

with open("sample.txt","r") as f:
    print(f.read())

# %% [markdown]
# ## Object-Oriented Programming
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def display(self):
        print(self.name,self.marks)

s=Student("Prathibha",95)
s.display()

# %% [markdown]
# ## NumPy Basics
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
import numpy as np

arr=np.array([10,20,30,40])
print(arr)
print("Mean:",np.mean(arr))
print("Max:",np.max(arr))
print("Min:",np.min(arr))

matrix=np.array([[1,2],[3,4]])
print(matrix)

# %% [markdown]
# ## Pandas Basics
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
import pandas as pd

data={
    "Name":["A","B","C","D"],
    "Age":[20,21,22,23],
    "Marks":[88,45,91,67]
}

df=pd.DataFrame(data)
print(df)
print(df.describe())

# %% [markdown]
# ## CSV Handling
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
df.to_csv("sample_data.csv",index=False)
df2=pd.read_csv("sample_data.csv")
print(df2.head())

# %% [markdown]
# ## Mini AI/ML Preprocessing
#
# **Interview Tip:** Understand this concept and be able to explain why it is useful in AI/ML.

# %%
df["Result"]=df["Marks"].apply(lambda x:"Pass" if x>=50 else "Fail")
print(df)

# Features (X) and Target (y)
X=df[["Age","Marks"]]
y=df["Result"]

print("Features:")
print(X)
print("Target:")
print(y)

# %% [markdown]
# # Common Interview Questions
#
# 1. Why is Python popular for AI/ML?
# 2. Difference between List and Tuple.
# 3. Difference between Dictionary and Set.
# 4. What is NumPy?
# 5. What is Pandas?
# 6. What are X and y in Machine Learning?
# 7. Why preprocess data?
# 8. What is OOP?
# 9. What is exception handling?
# 10. Difference between `==` and `is`.
#
# ## Conclusion
#
# This notebook covers Python fundamentals required for AI/ML and serves as a foundation for advanced machine learning libraries such as Scikit-learn, TensorFlow, and PyTorch.
